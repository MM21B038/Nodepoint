# %%
import os
import django

os.environ.setdefault("DJANGO_SETTINGS_MODULE", "config.settings")
django.setup()

# %%
from nodepoint.agent.agent import Agent
from nodepoint.registry import Thread, Prompt, Schema
from nodepoint.backend.kg_builder import get_entity_types, entity_types_as_md_table, extract_entities

# %%
agent = Agent()
thread = Thread()

# %%
entity_types = set(get_entity_types().keys())

# %%
md_entity_types = entity_types_as_md_table(get_entity_types())

# %%
doc = """
24*7 -> water and Tea
No Onion & No Garlic

7th Feb

Breakfast
Bedai and Sabji
Indori Poha
Dhokla
Samosa with green and red chutney + (sabji)
+  Corn Flakes and Oats with Milk
Kesariya Dahi Jalebi


Lunch

Welcome Starter (Serving)
-  Veg corns
French Fries
Dahi ke Sholey
Fresh Juice
-  Bundi Jaljeera

Main Course
Gatte ki sabji
Masala Aloo
Rajasthani Kadi
Panchmel Dal
-  Jeera Rice
+  Pulav (dry fruit)
Masala Bati
Mirchi Bada
Wafle
Tikker
Tava Roti
-  Missi Roti
-  Green Chutney
+  Red Chutney
Kachumar Salad
Papad
+ (Badam Kesar Milk)
Churma Laddu**(4 Types) ?**
-  Bajre ki kheer
+  Malpua


Dinner

Starter (Live & Serving)
Masala Paneer Tikka
Cheese Ball
Dahi ke sholey
Veg Dry Manchurian
+  Chilly Potato

Soup (Live & Serving)
Tomato Soup
Hot & Sour Soup

Chat Corner
Pani Puri (Rawa/Aata) (with 3 flavours)
-  Dry Fruit Chaat
+  Papdi Chaat or Sev Puri
Aloo Tikki
Tomato Chaat (Banarasi)

Main Course
Dal fry
Kadai Paneer
Mix Veg
+  ? Kofta Sabji
Tava Roti
Tandoori Roti
Naan Missi Roti
+  Salad

Sweet
Gulab Jamun
Rabdi
+  Moong Dal Halwa
+  Single Flavoured Ice Cream



8th Feb

Breakfast
Masala Dosa
-  Mehsur Masala Dosa
+  Ghee/Butter Dosa
Idli
Vada
Coconut Chutney
Tomato Chutney
Sambhar
-  Mix Pakodi (with Green and Red Chutney)
+  Aloo Paratha with Butter, Green Chutney and Raita
+  Mix Veg Paratha with Butter, Green Chutney and Raita
+  Corn Flakes and Oats with Milk
Rava Kesari (Sooji Pineapple Halwa)

Lunch
-  Kashmiri Dum Aloo
+  Haridwar Dum Aloo
Dal Tadka
Mix Veg
-  Bathua Raita
+  Baigan Ka Bharta
Jeera Rice
Tawa Roti
Missi Roti
Rajasthani Boondi Laddu

Dinner

Mocktails
Virgin Mojito
Blue Lagoon

Shake
Chocolate Crunchy Shake
Paan Shake

Fresh Juice
Orange Juice
Cranberry Juice

Starter (Live & Serving)
Malai Paneer Tikka
Corn Cheese Ball
Hara Bhara Kabab
Veg Spring Roll (stuffed with Paneer and Vegies)
-  Malai Chaap
+  Masala Chaap
+  Veg Dry Manchurian
Cheese Cigar Roll

Soup Hut
Sweet Corn Soup
Tomato Soup with Cream

Italian Live Pasta Station
Farfel (Served with a variety of Sauces):
    - Basil Tomato Sauce
    - Creamy Basil & Cheese Sauce

Bakery
Thin Crust Pizza
Fruit Putting

Chat Corner
Pani Puri (Rawa/Aata) (with 3 flavours) (Separate Counter)
Paneer Chila
Paneer Aloo Tikki
Dahi Bhalla
Pav Bhaji

Punjabi Counter
Amritsari Chola
Amritsari Kulcha
Amritsari Chutney
Dal Makhani
Patyala Paneer
Sarso ka saag
Veg Pulav
Makke Ki Roti
Bajre Ki Roti
Achar Variety
Salad Variety
Chutney Variety
Gud
Makkhan

Salad Counter
Fresh Garden Green Salad
Three Bean Salad

Main Course
Paneer Lababdar
Malai Paneer Kofta
Kashmiri Dum Aloo
Kadi
Dal Tadka
Fruit Raita
Tava Rti
Missi Roti
Laccha Paratha
Butter Nan
?  Puri(Plane + Missi)

+  Tawa Veg Counter

Sahi Sweet
Jalebi Rabdi
Gajar Halwa
Makkhan Santra
Moong Dal Halwa
Sunday Ice Cream
Live Corn
Doodh Kadai
"""

# %%
print(entity_types)
# Out:
# {'IP', 'MALWARE', 'SUBDOMAIN', 'PER', 'ORG', 'LOC', 'OTHER', 'VULN', 'EVENT', 'TOOL', 'DOMAIN', 'TECH', 'PROD'}

# %%
response = extract_entities(doc=doc, entity_types = entity_types, md_entity_table=md_entity_types, agent=agent)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~/Desktop/Nodepoint/nodepoint/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#
# File ~/Desktop/Nodepoint/nodepoint/.venv/lib/python3.14/site-packages/urllib3/connection.py:571, in HTTPConnection.getresponse(self)
#     570 # Get the response from http.client.HTTPConnection
# --> 571 httplib_response = super().getresponse()
#     573 try:
#
# File ~/.local/share/uv/python/cpython-3.14.5-linux-x86_64-gnu/lib/python3.14/http/client.py:1459, in HTTPConnection.getresponse(self)
#    1458 try:
# -> 1459     response.begin()
#    1460 except ConnectionError:
#
# File ~/.local/share/uv/python/cpython-3.14.5-linux-x86_64-gnu/lib/python3.14/http/client.py:336, in HTTPResponse.begin(self)
#     335 while True:
# --> 336     version, status, reason = self._read_status()
#     337     if status != CONTINUE:
#
# File ~/.local/share/uv/python/cpython-3.14.5-linux-x86_64-gnu/lib/python3.14/http/client.py:297, in HTTPResponse._read_status(self)
#     296 def _read_status(self):
# --> 297     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     298     if len(line) > _MAXLINE:
#
# File ~/.local/share/uv/python/cpython-3.14.5-linux-x86_64-gnu/lib/python3.14/socket.py:729, in SocketIO.readinto(self, b)
#     728 try:
# --> 729     return self._sock.recv_into(b)
#     730 except timeout:
#
# File ~/.local/share/uv/python/cpython-3.14.5-linux-x86_64-gnu/lib/python3.14/ssl.py:1316, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1313         raise ValueError(
#    1314           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1315           self.__class__)
# -> 1316     return self.read(nbytes, buffer)
#    1317 else:
#
# File ~/.local/share/uv/python/cpython-3.14.5-linux-x86_64-gnu/lib/python3.14/ssl.py:1150, in SSLSocket.read(self, len, buffer)
#    1149 if buffer is not None:
# -> 1150     return self._sslobj.read(len, buffer)
#    1151 else:
#
# TimeoutError: The read operation timed out
#
# The above exception was the direct cause of the following exception:
#
# ReadTimeoutError                          Traceback (most recent call last)
# File ~/Desktop/Nodepoint/nodepoint/.venv/lib/python3.14/site-packages/requests/adapters.py:696, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     695 try:
# --> 696     resp = conn.urlopen(
#     697         method=request.method,
#     698         url=url,
#     699         body=request.body,  # type: ignore[arg-type]  # urllib3 stubs don't accept Iterable[bytes | str]
#     700         headers=request.headers,  # type: ignore[arg-type]  # urllib3#3072
#     701         redirect=False,
#     702         assert_same_host=False,
#     703         preload_content=False,
#     704         decode_content=False,
#     705         retries=self.max_retries,
#     706         timeout=resolved_timeout,
#     707         chunked=chunked,
#     708     )
#     710 except (ProtocolError, OSError) as err:
#
# File ~/Desktop/Nodepoint/nodepoint/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:842, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     840     new_e = ProtocolError("Connection aborted.", new_e)
# --> 842 retries = retries.increment(
#     843     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     844 )
#     845 retries.sleep()
#
# File ~/Desktop/Nodepoint/nodepoint/.venv/lib/python3.14/site-packages/urllib3/util/retry.py:498, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     497 if read is False or method is None or not self._is_method_retryable(method):
# --> 498     raise reraise(type(error), error, _stacktrace)
#     499 elif read is not None:
#
# File ~/Desktop/Nodepoint/nodepoint/.venv/lib/python3.14/site-packages/urllib3/util/util.py:39, in reraise(tp, value, tb)
#      38         raise value.with_traceback(tb)
# ---> 39     raise value
#      40 finally:
#
# File ~/Desktop/Nodepoint/nodepoint/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:788, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787 # Make the request on the HTTPConnection object
# --> 788 response = self._make_request(
#     789     conn,
#     790     method,
#     791     url,
#     792     timeout=timeout_obj,
#     793     body=body,
#     794     headers=headers,
#     795     chunked=chunked,
#     796     retries=retries,
#     797     response_conn=response_conn,
#     798     preload_content=preload_content,
#     799     decode_content=decode_content,
#     800     **response_kw,
#     801 )
#     803 # Everything went great!
#
# File ~/Desktop/Nodepoint/nodepoint/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 except (BaseSSLError, OSError) as e:
# --> 536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#     537     raise
#
# File ~/Desktop/Nodepoint/nodepoint/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:367, in HTTPConnectionPool._raise_timeout(self, err, url, timeout_value)
#     366 if isinstance(err, SocketTimeout):
# --> 367     raise ReadTimeoutError(
#     368         self, url, f"Read timed out. (read timeout={timeout_value})"
#     369     ) from err
#     371 # See the above comment about EAGAIN in Python 3.
#
# ReadTimeoutError: HTTPSConnectionPool(host='api.ai.oac', port=443): Read timed out. (read timeout=120.0)
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeout                               Traceback (most recent call last)
# File ~/Desktop/Nodepoint/nodepoint/nodepoint/agent/agent.py:367, in Agent._request(self, method, path, payload)
#     366 try:
# --> 367     resp = self.session.request(
#     368         method=method,
#     369         url=url,
#     370         json=payload,
#     371         verify=self.verify_ssl,
#     372         timeout=self._request_timeout(),
#     373     )
#     374     if not resp.ok:
#
# File ~/Desktop/Nodepoint/nodepoint/.venv/lib/python3.14/site-packages/requests/sessions.py:651, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     650 send_kwargs.update(settings)
# --> 651 resp = self.send(prep, **send_kwargs)
#     653 return resp
#
# File ~/Desktop/Nodepoint/nodepoint/.venv/lib/python3.14/site-packages/requests/sessions.py:784, in Session.send(self, request, **kwargs)
#     783 # Send the request
# --> 784 r = adapter.send(request, **kwargs)
#     786 # Total elapsed time of the request (approximately)
#
# File ~/Desktop/Nodepoint/nodepoint/.venv/lib/python3.14/site-packages/requests/adapters.py:742, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     741 elif isinstance(e, ReadTimeoutError):
# --> 742     raise ReadTimeout(e, request=request)
#     743 elif isinstance(e, _InvalidHeader):
#
# ReadTimeout: HTTPSConnectionPool(host='api.ai.oac', port=443): Read timed out. (read timeout=120.0)
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 response = extract_entities(doc=doc, entity_types = entity_types, md_entity_table=md_entity_types, agent=agent)
#
# File ~/Desktop/Nodepoint/nodepoint/nodepoint/backend/kg_builder.py:61, in extract_entities(doc, entity_types, md_entity_table, agent)
#      58 NewEntities = Entities(types=entity_types)
#      60 while trial < TRIALS:
# ---> 61     response = agent.parse(
#      62         messages=thread,
#      63         model=agent.model,
#      64         response_schema=NewEntities,
#      65         temperature=EXTRACTION_TEMPERATURE,
#      66     )
#      67     if isinstance(response, AgentParseSuccessResult):
#      68         return response.response.entities
#
# File ~/Desktop/Nodepoint/nodepoint/nodepoint/agent/agent.py:843, in Agent.parse(self, messages, model, response_schema, response_format, temperature, reasoning)
#     832     response_format = {"type": "json_object"}
#     834 payload = {
#     835     "model": model,
#     836     "messages": messages.to_json(),
#    (...)    840     "reasoning": {"effort": reasoning}
#     841 }
# --> 843 raw_response = self._request("POST", "/chat/completions", payload)
#     845 if "error" in raw_response:
#     846     raise RuntimeError(
#     847         f"API Error: {raw_response['error']}"
#     848     )
#
# File ~/Desktop/Nodepoint/nodepoint/nodepoint/agent/agent.py:380, in Agent._request(self, method, path, payload)
#     378     return resp.json()
#     379 except requests.RequestException as e:
# --> 380     raise RuntimeError(f"Request failed for {path}: {e}") from e
#     381 except ValueError as e:
#     382     raise RuntimeError(f"Server returned invalid JSON for {path}") from e
#
# RuntimeError: Request failed for /chat/completions: HTTPSConnectionPool(host='api.ai.oac', port=443): Read timed out. (read timeout=120.0)

# %%
response
# Out:
# [Entity(name='Food Items', type='OTHER', newtype='FOOD_ITEM', attributes={'items': ['Bedai and Sabji', 'Indori Poha', 'Dhokla', 'Samosa', 'Corn Flakes and Oats with Milk', 'Kesariya Dahi Jalebi', 'Veg corns', 'French Fries', 'Dahi ke Sholey', 'Fresh Juice', 'Bundi Jaljeera', 'Gatte ki sabji', 'Masala Aloo', 'Rajasthani Kadi', 'Panchmel Dal', 'Jeera Rice', 'Pulav (dry fruit)', 'Masala Bati', 'Mirchi Bada', 'Wafle', 'Tikker', 'Tava Roti', 'Missi Roti', 'Green Chutney', 'Red Chutney', 'Kachumar Salad', 'Papad', 'Badam Kesar Milk', 'Churma Laddu', 'Bajre ki kheer', 'Malpua', 'Masala Paneer Tikka', 'Cheese Ball', 'Veg Dry Manchurian', 'Chilly Potato', 'Tomato Soup', 'Hot & Sour Soup', 'Pani Puri', 'Dry Fruit Chaat', 'Papdi Chaat', 'Sev Puri', 'Aloo Tikki', 'Tomato Chaat (Banarasi)', 'Dal fry', 'Kadai Paneer', 'Mix Veg', 'Kofta Sabji', 'Tandoori Roti', 'Naan Missi Roti', 'Salad', 'Gulab Jamun', 'Rabdi', 'Moong Dal Halwa', 'Single Flavoured Ice Cream', 'Masala Dosa', 'Mehsur Masala Dosa', 'Ghee/Butter Dosa', 'Idli', 'Vada', 'Coconut Chutney', 'Tomato Chutney', 'Sambhar', 'Mix Pakodi', 'Aloo Paratha with Butter, Green Chutney and Raita', 'Mix Veg Paratha with Butter, Green Chutney and Raita', 'Rava Kesari (Sooji Pineapple Halwa)', 'Kashmiri Dum Aloo', 'Haridwar Dum Aloo', 'Dal Tadka', 'Bathua Raita', 'Baigan Ka Bharta', 'Rajasthani Boondi Laddu', 'Virgin Mojito', 'Blue Lagoon', 'Chocolate Crunchy Shake', 'Paan Shake', 'Orange Juice', 'Cranberry Juice', 'Malai Paneer Tikka', 'Corn Cheese Ball', 'Hara Bhara Kabab', 'Veg Spring Roll', 'Masala Chaap', 'Cheese Cigar Roll', 'Sweet Corn Soup', 'Tomato Soup with Cream', 'Farfel', 'Basil Tomato Sauce', 'Creamy Basil & Cheese Sauce', 'Thin Crust Pizza', 'Fruit Putting', 'Paneer Chila', 'Paneer Aloo Tikki', 'Dahi Bhalla', 'Pav Bhaji', 'Amritsari Chola', 'Amritsari Kulcha', 'Amritsari Chutney', 'Dal Makhani', 'Patyala Paneer', 'Sarso ka saag', 'Veg Pulav', 'Makke Ki Roti', 'Bajre Ki Roti', 'Achar Variety', 'Salad Variety', 'Chutney Variety', 'Gud', 'Makkhan', 'Fresh Garden Green Salad', 'Three Bean Salad', 'Paneer Lababdar', 'Malai Paneer Kofta', 'Kadi', 'Fruit Raita', 'Laccha Paratha', 'Butter Nan', 'Puri (Plane + Missi)', 'Tawa Veg Counter', 'Jalebi Rabdi', 'Gajar Halwa', 'Makkhan Santra', 'Sunday Ice Cream', 'Live Corn', 'Doodh Kadai']})]

# %%
thread = Thread()

# %%
thread.addUser("hi")

# %%
agent.parse(thread)

# %%
thread.addSystem(Prompt["entity_extractor_system"])
# Out:
# 49946af6-8823-4a70-803d-5f4506c2010e Rustscan Scans and identifies 115.124.100.16 7858_Rustscan_2026-05-01T04:28:31.693383.txt
# c445fc51-3b30-4068-8f93-385a6c13bf80 Rustscan Scans and identifies 443/tcp 7858_Rustscan_2026-05-01T04:28:31.693383.txt
# f45c8af2-c590-4445-a20c-f08c5b769404 115.124.100.16 Hosts open port 443/tcp 7858_Rustscan_2026-05-01T04:28:31.693383.txt
# 83dc7b44-db3e-4b5e-996a-1269a243a757 443/tcp Runs HTTPS service HTTPS 7858_Rustscan_2026-05-01T04:28:31.693383.txt
# d9a21d5d-29ad-4dba-868a-332dca00b340 HTTPS Uses TCP protocol tcp 7858_Rustscan_2026-05-01T04:28:31.693383.txt
# 68ecfe3f-4389-4e6e-9d8e-8224dc47a264 Rustscan Uses Nmap engine Nmap 7.95 7858_Rustscan_2026-05-01T04:28:31.693383.txt
# c1ca85f0-feec-42de-b14f-33954e7ed403 Nmap 7.95 Is version of Nmap 7858_Rustscan_2026-05-01T04:28:31.693383.txt
# b02565fe-7bce-4ee9-8740-3d76d8aecdfe https://admin.tryhackme.com Contains domain admin.tryhackme.com 7858_Rustscan_2026-05-01T04:28:31.693383.txt
# ebfbe549-0165-4975-9b2e-17460757bcc4 admin.tryhackme.com Is subdomain of tryhackme.com 7858_Rustscan_2026-05-01T04:28:31.693383.txt

# %%
thread.addUser(Prompt["entity_extractor_user"].format(entity_types=md_entity_types, doc=doc))

# %%
resp = agent.parse(thread)

# %%
resp.response
# Out:
# 'Invalid JSON response'

# %%
thread.addAssistant(resp.message)

# %%
resp = agent.parse(thread)

# %%
resp.message
# Out:
# ChatCompletionMessage(role='assistant', content=None, tool_calls=None, reasoning_content=None, reasoning='We need to extract entities from this menu document. Entities types: PER, ORG, LOC, PROD, EVENT, TECH, VULN, MALWARE, TOOL, IP, DOMAIN, SUBDOMAIN, OTHER.\n\nThe doc is a menu with food items, dates, etc. Likely entities are food items, which are not covered by existing types. Could be considered OTHER. Could create new type "FOOD" maybe. The instruction: we can create new entity type if needed. So we should create newtype "FOOD" with description "Name of food dishes or items". Then list each distinct food item as entity with type FOOD (or type OTHER with newtype?). The format: each entity has fields name, type, newtype (only if type=OTHER). But we can also set type to FOOD if we register newtype? Actually they said: If none of the entity types match, choose type OTHER and then provide newtype name. So we must set type "OTHER" and newtype "FOOD". Or we could add new type to list? The spec: "You have a freedom to use and create an new entity type and add it. if needed other then in `Entity Types`:\n* In case of none of the entity types match the entity relevant to the doc, choose type `OTHER`.\n* and then provide the `newtype` -> Name of the new entity type, naming should be as per the convention.\n* then add the `newtype` and short `description` of the new entity type in `new_types` to get it registered."\n\nThus for each entity we set type "OTHER" and newtype "FOOD". Or we could set type "FOOD" directly? The instruction says choose type OTHER, then provide newtype. So we must follow that.\n\nNow we need to extract all relevant entities. That could be many food items. Might be too many. Perhaps we only need distinct items. Let\'s list them.\n\nFrom doc:\n\nDates: "7th Feb", "8th Feb". Could be EVENT? Could be DATE but not in types. Could be OTHER with newtype "DATE". But maybe not needed. The instruction: extract relevant entities. Food items are relevant. Dates maybe not. Let\'s focus on food items.\n\nList:\n\nBreakfast items day 7:\n\n- Bedai and Sabji\n- Indori Poha\n- Dhokla\n- Samosa with green and red chutney + (sabji)\n- Corn Flakes and Oats with Milk\n- Kesariya Dahi Jalebi\n\nLunch day 7:\n\nWelcome Starter (Serving) - Veg corns\nFrench Fries\nDahi ke Sholey\nFresh Juice\nBundi Jaljeera\n\nMain Course:\nGatte ki sabji\nMasala Aloo\nRajasthani Kadi\nPanchmel Dal\nJeera Rice\nPulav (dry fruit)\nMasala Bati\nMirchi Bada\nWafle\nTikker\nTava Roti\nMissi Roti\nGreen Chutney\nRed Chutney\nKachumar Salad\nPapad\nBadam Kesar Milk\nChurma Laddu (4 Types) ?\nBajre ki kheer\nMalpua\n\nDinner day 7:\n\nStarter (Live & Serving):\nMasala Paneer Tikka\nCheese Ball\nDahi ke sholey\nVeg Dry Manchurian\nChilly Potato\n\nSoup:\nTomato Soup\nHot & Sour Soup\n\nChat Corner:\nPani Puri (Rawa/Aata) (with 3 flavours)\nDry Fruit Chaat\nPapdi Chaat or Sev Puri\nAloo Tikki\nTomato Chaat (Banarasi)\n\nMain Course:\nDal fry\nKadai Paneer\nMix Veg\n? Kofta Sabji\nTava Roti\nTandoori Roti\nNaan Missi Roti\nSalad\n\nSweet:\nGulab Jamun\nRabdi\nMoong Dal Halwa\nSingle Flavoured Ice Cream\n\nDay 8:\n\nBreakfast:\nMasala Dosa\nMehsur Masala Dosa\nGhee/Butter Dosa\nIdli\nVada\nCoconut Chutney\nTomato Chutney\nSambhar\nMix Pakodi (with Green and Red Chutney)\nAloo Paratha with Butter, Green Chutney and Raita\nMix Veg Paratha with Butter, Green Chutney and Raita\nCorn Flakes and Oats with Milk\nRava Kesari (Sooji Pineapple Halwa)\n\nLunch:\nKashmiri Dum Aloo\nHaridwar Dum Aloo\nDal Tadka\nMix Veg\nBathua Raita\nBaigan Ka Bharta\nJeera Rice\nTawa Roti\nMissi Roti\nRajasthani Boondi Laddu\n\nDinner:\n\nMocktails:\nVirgin Mojito\nBlue Lagoon\n\nShake:\nChocolate Crunchy Shake\nPaan Shake\n\nFresh Juice:\nOrange Juice\nCranberry Juice\n\nStarter (Live & Serving):\nMaliki Paneer Tikka? Actually "Malai Paneer Tikka"\nCorn Cheese Ball\nH{ } "Hara\n\n  "  Hara\n\n  "  Hara\n\n  "  Hara Bh\n\n  "  Hara\n\n  "  Hara\n\n  "  "  "  "  "  "  "  "  \n\n"  "  "  "   ...

# %%
import tiktoken

encoding = tiktoken.get_encoding("o200k_harmony")

tokens = encoding.encode(doc)

print("Token count:", len(tokens))
# Out:
# Token count: 997
